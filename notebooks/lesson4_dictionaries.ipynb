# %% [markdown]
#  # Python Crase Course -Lesson 4
#  This lesson covers Chapter 6:
# Dictionaries connect pieces of related information. As with most new programming concepts, using dictionaries takes practice. Once you’ve worked with dictionaries for a bit you’ll soon see how effectively they can model real-world situations.
#  - Dictionary: {'key1':'value1','key2':'value2'}
#                 define by starting with an empty {}
#  - Changes in Dictionaries:
#                         alien_0['points'] = 1 # change or add
#                         del alien_0['points'] # delete pair
#  - Loop in Dictionaries:
#                         for key, value in user_0.items():
#                             print(f"\nKey: {key}")
#                             print(f"Value: {value}")
#                         user_0.items() # list of key-value pairs
#                         user_0.keys() # list of all keys
#                         user_0.values() # list of all values
#  - Nest Dictionaries and lists in each other

# %%
# Define a dictionarey 
alien_0 = {'color':'green','points':5}
print(alien_0['color'])
print(alien_0['points'])
new_points = alien_0['points']
print(f"you just earned {new_points} points!")

# Modify values in a dictionary
alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")

# Add new key-value pair 
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)

#  Moving an alien using dictionary
## Define an empty dictionary and add key-value
alien_0 = {}
alien_0['x_position'] = 0
alien_0['y_position'] = 25
alien_0['speed'] = 'medium'
alien_0['points'] = 5
print(f"\nOrigional x-position: {alien_0['x_position']}")
## Move the alien to the right. 
## Determin how far to move the alien based on its current speed. 
if alien_0['speed'] == 'slow':
    x_increment = 1
elif alien_0['speed'] == 'medium':
    x_increment = 2
else: 
    ## This must be a fast alien
    x_increment = 3
## New position is the old x_position + x_increment
alien_0['x_position'] += x_increment
print(f"New x-position: {alien_0['x_position']}")

# Removing Key-Value pairs
print(alien_0)
del alien_0['points']
print(f"del alien_0['points'] deletes a pair: \n{alien_0}")
# Out:
# green
# 5
# you just earned 5 points!
# The alien is now yellow.
# {'color': 'yellow', 'points': 5, 'x_position': 0, 'y_position': 25}
#
# Origional x-position: 0
# New x-position: 2
# {'x_position': 2, 'y_position': 25, 'speed': 'medium', 'points': 5}
# del alien_0['points'] deletes a pair:
# {'x_position': 2, 'y_position': 25, 'speed': 'medium'}

# %% [markdown]
# # When to use a dictionary
# - Dictionary: storing different kinds of information about one object, an alien in a game.
# - Dictionary: to store one kind of information about many objects, a poll of favorite programming languages.

# %%
# Stying: Need more than one line to define a dictionary, 
# press enter after the opening brace. 
favourite_languages = {
    'jen':'python',
    'sarah':'c',
    'edward':'ruby',
    'phil':'python'
}
print(f"Sarah's favourite language is {favourite_languages['sarah'].title()}")
# Breaking long print statement to increase readability.
print(f"Jen's favourite language is" 
      f"{favourite_languages['jen'].title()}.")
# Out:
# Sarah's favourite language is C
# Jen's favourite language isPython.

# %%
# --- Exercise 6-1. to 6-4. ---
amis_kohls = {}
amis_kohls['first_name'] = 'kohls'
amis_kohls['last_name'] = 'noord'
amis_kohls['age'] = 28
amis_kohls['height'] = 165 
amis_kohls['city'] = 'kyoto'
print(amis_kohls)
python_glossary = {
    'string':'a series of words',
    'list':'a collection of items in numerical order',
    'dictionary':'a collection of items in key-value pairs',
    'loop':'a block of code that repeats',
    'if statement':'a block of code that executes if the condition is True',
    'boolean':'a value that can be either True or False',
    'styling':'make your code readable and beautiful'
}
print(python_glossary)
# Looping through a dictionary
for word, definition in python_glossary.items():
    print(f"\n Key: {word.title()} \n Value: {definition}")
# Out:
# {'first_name': 'kohls', 'last_name': 'noord', 'age': 28, 'height': 165, 'city': 'kyoto'}
# {'string': 'a series of words', 'list': 'a collection of items in numerical order', 'dictionary': 'a collection of items in key-value pairs', 'loop': 'a block of code that repeats', 'if statement': 'a block of code that executes if the condition is True', 'boolean': 'a value that can be either True or False', 'styling': 'make your code readable and beautiful'}
#
#  Key: String
#  Value: a series of words
#
#  Key: List
#  Value: a collection of items in numerical order
#
#  Key: Dictionary
#  Value: a collection of items in key-value pairs
#
#  Key: Loop
#  Value: a block of code that repeats
#
#  Key: If Statement
#  Value: a block of code that executes if the condition is True
#
#  Key: Boolean
#  Value: a value that can be either True or False
#
#  Key: Styling
#  Value: make your code readable and beautiful

# %%
# Looping through a dictionary to print only keys or values
# dictionary.items() method returns a list of key-value pairs.
# dictionary.keys() method returns a list of keys.
# dictionary.values() method returns a list of values.
print(amis_kohls.items())
print(amis_kohls.keys())
print(amis_kohls.values())
# loop through a dictionary to print only keys or values
for k,v in amis_kohls.items():
    print(f"\nKey: {k} \nValue: {v}")
# dictionary.keys() method returns a list of keys in the dictionary.  
for k in amis_kohls.keys():
    print(f"Key: {k}")

if 'erin' not in favourite_languages.keys():
    print("\nErin, please take our poll!")

# Sorting a dictionary by keys or values
## sorted() function returns a sorted list of the specified iterable object.
for name in sorted(favourite_languages.keys()):
    print(f"{name.title()}, thank you for taking the poll.")
## To get a list of values without duplicates, use set() function to remove duplicates.
for language in set(favourite_languages.values()):
    print(language)
# Out:
# dict_items([('first_name', 'kohls'), ('last_name', 'noord'), ('age', 28), ('height', 165), ('city', 'kyoto')])
# dict_keys(['first_name', 'last_name', 'age', 'height', 'city'])
# dict_values(['kohls', 'noord', 28, 165, 'kyoto'])
#
# Key: first_name
# Value: kohls
#
# Key: last_name
# Value: noord
#
# Key: age
# Value: 28
#
# Key: height
# Value: 165
#
# Key: city
# Value: kyoto
# Key: first_name
# Key: last_name
# Key: age
# Key: height
# Key: city
#
# Erin, please take our poll!
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.
# c
# python
# ruby

# %%
# --- Exercise 6-5. ---
rivers= {'nile':'egypt', 'amazon':'brazil', 'yangtze':'china','long':'china'}
for river, country in rivers.items():
    print(f"The {river.title()} runs through {country.title()}")
print("The rivers in the dictionary are:")
for river in sorted(rivers.keys()):
    print(river.title())
print("The countries in the dictionary are:")
for country in sorted(set(rivers.values())):
    print(country.title())
# --- Exercise 6-6. ---
names = ['sarah', 'phil', 'jen', 'edward', 'erin','kohls']
for name in names:
    if name in favourite_languages.keys():
        print(f"{name.title()} thanks you for talking the poll.")
    else:
        print(f"{name.title()} please take the poll")
# Out:
# The Nile runs through Egypt
# The Amazon runs through Brazil
# The Yangtze runs through China
# The Long runs through China
# The rivers in the dictionary are:
# Amazon
# Long
# Nile
# Yangtze
# The countries in the dictionary are:
# Brazil
# China
# Egypt
# Sarah thanks you for talking the poll.
# Phil thanks you for talking the poll.
# Jen thanks you for talking the poll.
# Edward thanks you for talking the poll.
# Erin please take the poll
# Kohls please take the poll

# %% [markdown]
# # Nesting Dictionaries and lists in each other
# - Nesting a list in a dictionary: store multiple values in a dictionary.
# - Nesting a dictionary in a dictionary: store dictionaries inside a dictionary.

# %%
# Nesting:  a list of dictionaries
alien_0 = {'color':'green','points':5}
alien_1 = {'color':'yellow','points':10}
alien_2 = {'color':'red','points':15}
aliens = [alien_0, alien_1, alien_2]
print(aliens)
for alien in aliens:
    print(alien)

## making a list of 30 aliens
aliens = []
for alien_number in range(30):
    new_alien = {'color':'green','points':5, 'speed':'slow','number':alien_number}
    aliens.append(new_alien)
### show the first 5 aliens
for alien in aliens[:5]:
    print(alien)
print("...")
### show how many aliens have been created
print(f"The total number of aliens: {len(aliens)}")

### modify aliens
for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10
### show the first 5 aliens
for alien in aliens[:5]:
    print(alien)
print("...")
# Out:
# [{'color': 'green', 'points': 5}, {'color': 'yellow', 'points': 10}, {'color': 'red', 'points': 15}]
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 0}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 1}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 2}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 3}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 4}
# ...
# The total number of aliens: 30
# {'color': 'yellow', 'points': 10, 'speed': 'medium', 'number': 0}
# {'color': 'yellow', 'points': 10, 'speed': 'medium', 'number': 1}
# {'color': 'yellow', 'points': 10, 'speed': 'medium', 'number': 2}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 3}
# {'color': 'green', 'points': 5, 'speed': 'slow', 'number': 4}
# ...

# %%
# Nesting:  a list in a dictionary
## store information about a pizza being ordered. 
pizza = {
    'crust':'thick',
    'toppings':['mushrooms','extra cheese'],
}
## summarize the order. 
print(f"You ordered a {pizza['crust']} crust pizza" 
      f"with the following toppings: "
    )
for topping in pizza['toppings']:
    print(f"\t{topping}")

favourite_languages = {
    "jen":['python','ruby'],
    'sarah':['c'],
    'edward':['ruby','c'],
    'phil': ['python','haskell']
}

## multiple prefered languages
for name, languages in favourite_languages.items():
    print(f"\n{name.title()}'s favourites are:")
    for language in languages:
        print(f"\t {language.title()}")
# Out:
# You ordered a thick crust pizzawith the following toppings:
# 	mushrooms
# 	extra cheese
#
# Jen's favourites are:
# 	 Python
# 	 Ruby
#
# Sarah's favourites are:
# 	 C
#
# Edward's favourites are:
# 	 Ruby
# 	 C
#
# Phil's favourites are:
# 	 Python
# 	 Haskell

# %%
# nesting: a dictionary in a dictionary
## You can nest a dictionary inside another dictionary, but your code can get complicated quickly when you do.
## Notice that the structure of each user’s dictionary is identical. Although not required by Python, this structure makes nested dictionaries easier to work with. If each user’s dictionary had different keys, the code inside the for loop would be more complicated.
users = {
    'aeinstien': {
        'first':'albert',
        'last':'einstein',
        'location':'princeton',
    },
    'mcurie': {
        'first':'marie',
        'last':'curie',
        'location':'paris',
    },
}
for username, user_info in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']
    print(f"Full name: {full_name.title()}"
          f"\nLocation: {location.title()}")
# Out:
# Username: aeinstien
# Full name: Albert Einstein
# Location: Princeton
#
# Username: mcurie
# Full name: Marie Curie
# Location: Paris

# %%
# --- Exercise 6-7. ---
amis_alice = {}
amis_alice['first_name'] = 'alice'
amis_alice['last_name'] = 'fond'
amis_alice['age'] = 39
amis_alice['height'] = 160 
amis_alice['city'] = 'belgium'

amis_eddie = {}
amis_eddie['first_name'] = 'eddie'
amis_eddie['last_name'] = 'jos'
amis_eddie['age'] = 90
amis_eddie['height'] = 180 
amis_eddie['city'] = 'austrilia'

amis_kohls = {}
amis_kohls['first_name'] = 'kohls'
amis_kohls['last_name'] = 'noord'
amis_kohls['age'] = 28
amis_kohls['height'] = 165 
amis_kohls['city'] = 'kyoto'

people = [amis_alice,amis_eddie,amis_kohls]

for ami in people:
    print("\n")
    for k,v in ami.items():
        print(f"{k.title()}:{str(v).title()}")
# Out:
# First_Name:Alice
# Last_Name:Fond
# Age:39
# Height:160
# City:Belgium
#
#
# First_Name:Eddie
# Last_Name:Jos
# Age:90
# Height:180
# City:Austrilia
#
#
# First_Name:Kohls
# Last_Name:Noord
# Age:28
# Height:165
# City:Kyoto

# %%
# --- Exercise 6-8. ---

dog = {
'owner':'alice',
'age': 5,
'breed':'labrador',
}
cat = {
'owner':'eddie',
'age': 3,
'breed':'persian',
}
rabbit = {
'owner':'kohls',
'age': 2,
'breed':'netherland dwarf',
}
pets = [dog, cat, rabbit]
for pet in pets:
    print("\n") 
    for k,v in pet.items():
        print(f"{k.title()}:{str(v).title()}")
# Out:
# Owner:Alice
# Age:5
# Breed:Labrador
#
#
# Owner:Eddie
# Age:3
# Breed:Persian
#
#
# Owner:Kohls
# Age:2
# Breed:Netherland Dwarf

# %%
# --- Exercise 6-9. ---
print("I skip exercise 6-9, since it is similar to exercise 6-8.")
# --- Exercise 6-10. ---
print("I skip exercise 6-10, since it is similar to exercise 6-8.")
# --- Exercise 6-11. ---
cities = {
    'tokyo':{
        'country':'japan',
        'population': 37_000_000,
        'fact':'the largest metropolitan area in the world',
    },
    'paris':{
        'country':'france',
        'population': 11_000_000,
        'fact':'the city of love',
    },
    'kyoto':{
        'country':'japan',
        'population': 1_500_000,
        'fact':'the city of ten thousand shrines',
    },
}
for city, info in cities.items():
    print(f"\nThe info about {city.title()} is as follows")
    for k,v in info.items():
        print(f"{k.title()}: {v}")
# Out:
# I skip exercise 6-9, since it is similar to exercise 6-8.
# I skip exercise 6-10, since it is similar to exercise 6-8.
#
# The info about Tokyo is as follows
# Country: japan
# Population: 37000000
# Fact: the largest metropolitan area in the world
#
# The info about Paris is as follows
# Country: france
# Population: 11000000
# Fact: the city of love
#
# The info about Kyoto is as follows
# Country: japan
# Population: 1500000
# Fact: the city of ten thousand shrines
